# %%
import pandas as pd

# %%
df_normal = pd.read_csv('../../data/normal_data.csv')

# %%
df_normal.columns = ['engine', 'Month', 'Fan Blade Noise', 'EGT', 'Fuel Flow', 'Low Pressure Fan Speed', 'High Pressure Rotor Speed', 'FP Fan Blade', 'FP EGT', 'FP Fuel Flow', 'FP Low Pressure Fan Speed', 'FP High Pressure Rotor Speed', 'FP Entire Turbine']
df_normal.head(2).append(df_normal.iloc[28:34]).append(df_normal.tail(3))
# Out:
#     engine  Month  Fan Blade Noise   EGT  Fuel Flow  Low Pressure Fan Speed  \
# 0      1.0      1       130.000000  1300       5000                   12000
# 1      1.0      2       130.217258  1319       5016                   12069
# 28     1.0     29       136.144380  1873       5469                   13918
# 29     1.0     30       136.376055  1891       5486                   13989
# 30     1.0     31       136.592820  1911       5503                   14056
# 31     1.0     32       136.822490  1930       5521                   14122
# 32     1.0     33       137.030876  1952       5537                   14193
# 33     1.0     34       137.255432  1974       5555                   14258
# 57     1.0     58       142.589947  2472       5969                   15891
# 58     1.0     59       142.822735  2492       5985                   15956
# 59     1.0     60       143.050874  2514       6001                   16024
#
#     High Pressure Rotor Speed  FP Fan Blade    FP EGT  FP Fuel Flow  \
# 0                       10000      0.000000  0.000000         0.000
# 1                       10068      0.000000  0.000000         0.000
# 28                      11935      0.000000  0.000000         0.000
# 29                      12006      0.000000  0.000000         0.000
# 30                      12074      0.000000  0.018333         0.006
# 31                      12140      0.000000  0.050000         0.042
# 32                      12212      0.005146  0.086667         0.074
# 33                      12281      0.042572  0.123333         0.110
# 57                      13931      0.931658  0.953333         0.938
# 58                      13998      0.970456  0.986667         0.970
# 59                      14064      1.000000  1.000000         1.000
#
#     FP Low Pressure Fan Speed  FP High Pressure Rotor Speed  FP Entire Turbine
# 0                      0.0000                        0.0000           0.000000
# 1                      0.0000                        0.0000           0.000000
# 28                     0.0000                        0.0000           0.000000
# 29                     0.0000                        0.0030           0.000600
# 30                     0.0280                        0.0370           0.017867
# 31                     0.0610                        0.0700           0.044600
# 32                     0.0965                        0.1060           0.073663
# 33                     0.1290                        0.1405           0.109081
# 57                     0.9455                        0.9655           0.946798
# 58                     0.9780                        0.9990           0.980825
# 59                     1.0000                        1.0000           1.000000

# %%
df_train = pd.read_csv('../../data/train_data/train_data.csv')

# %%
df_train.columns = ['engine', 'Month', 'Fan Blade Noise', 'EGT', 'Fuel Flow', 'Low Pressure Fan Speed', 'High Pressure Rotor Speed', 'FP Fan Blade', 'FP EGT', 'FP Fuel Flow', 'FP Low Pressure Fan Speed', 'FP High Pressure Rotor Speed', 'FP Entire Turbine']
df_train.head(2).append(df_train.iloc[23:26]).append(df_train.iloc[49:54])
# Out:
#     engine  Month  Fan Blade Noise   EGT  Fuel Flow  Low Pressure Fan Speed  \
# 0        1      1       130.000000  1300       5000                   12000
# 1        1      2       130.436342  1332       5028                   12083
# 22       1     23       137.810221  1928       5416                   13790
# 23       1     24       138.320011  1953       5431                   13880
# 24       1     25       138.741395  1984       5446                   13960
# 25       1     26       138.959916  2018       5459                   14045
# 49       1     50       147.636077  2717       5934                   15943
# 50       1     51       147.857828  2757       5955                   16017
# 51       1     52       148.391431  2784       5971                   16111
# 52       1     53       148.546813  2815       5988                   16191
# 53       1     54       148.984539  2854       6007                   16266
#
#     High Pressure Rotor Speed  FP Fan Blade    FP EGT  FP Fuel Flow  \
# 0                       10000      0.000000  0.000000         0.000
# 1                       10080      0.000000  0.000000         0.000
# 22                      11805      0.135037  0.046667         0.000
# 23                      11879      0.220002  0.088333         0.000
# 24                      11948      0.290233  0.140000         0.000
# 25                      12040      0.326653  0.196667         0.000
# 49                      14010      1.000000  1.000000         0.868
# 50                      14080      1.000000  1.000000         0.910
# 51                      14152      1.000000  1.000000         0.942
# 52                      14244      1.000000  1.000000         0.976
# 53                      14323      1.000000  1.000000         1.000
#
#     FP Low Pressure Fan Speed  FP High Pressure Rotor Speed  FP Entire Turbine
# 0                      0.0000                          0.00           0.000000
# 1                      0.0000                          0.00           0.000000
# 22                     0.0000                          0.00           0.036341
# 23                     0.0000                          0.00           0.061667
# 24                     0.0000                          0.00           0.086047
# 25                     0.0225                          0.02           0.113164
# 49                     0.9715                          1.00           0.967900
# 50                     1.0000                          1.00           0.982000
# 51                     1.0000                          1.00           0.988400
# 52                     1.0000                          1.00           0.995200
# 53                     1.0000                          1.00           1.000000
