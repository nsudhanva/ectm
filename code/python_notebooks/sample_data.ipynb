# %%
import pandas as pd

# %%
df_normal = pd.read_csv('../../data/normal_data.csv')

# %%
df_normal.columns = ['engine', 'Month', 'Fan Blade Noise', 'EGT', 'Fuel Flow', 'Low Pressure Fan Speed', 'High Pressure Rotor Speed', 'FP Fan Blade', 'FP EGT', 'FP Fuel Flow', 'FP Low Pressure Fan Speed', 'FP High Pressure Rotor Speed', 'FP Entire Turbine']
df_normal.head(2).append(df_normal.iloc[28:34]).append(df_normal.tail(3))
# Out:
#     engine  Month  Fan Blade Noise   EGT  Fuel Flow  Low Pressure Fan Speed  \
# 0      1.0      1       130.000000  1300       5000                   12000
# 1      1.0      2       130.236460  1319       5018                   12065
# 28     1.0     29       136.163088  1878       5482                   13919
# 29     1.0     30       136.402686  1900       5498                   13991
# 30     1.0     31       136.638178  1923       5515                   14063
# 31     1.0     32       136.853412  1941       5532                   14130
# 32     1.0     33       137.090912  1961       5550                   14199
# 33     1.0     34       137.304148  1984       5566                   14269
# 57     1.0     58       142.548655  2471       5979                   15919
# 58     1.0     59       142.770258  2493       5996                   15985
# 59     1.0     60       143.000189  2516       6013                   16053
#
# ...

# %%
df_train = pd.read_csv('../../data/train_data/error_train_data.csv')

# %%
df_train.columns = ['engine', 'Month', 'Fan Blade Noise', 'EGT', 'Fuel Flow', 'Low Pressure Fan Speed', 'High Pressure Rotor Speed', 'FP Fan Blade', 'FP EGT', 'FP Fuel Flow', 'FP Low Pressure Fan Speed', 'FP High Pressure Rotor Speed', 'FP Entire Turbine']
df_train.head(2).append(df_train.iloc[22:28]).append(df_train.iloc[48:51])
# Out:
#     engine  Month  Fan Blade Noise   EGT  Fuel Flow  Low Pressure Fan Speed  \
# 0        1      1       130.000000  1300       5000                   12000
# 1        1      2       130.349440  1337       5010                   12072
# 22       1     23       136.995151  1906       5428                   13787
# 23       1     24       137.543611  1923       5439                   13865
# 24       1     25       138.055674  1938       5449                   13949
# 25       1     26       138.443011  1965       5472                   14034
# 26       1     27       138.801498  2002       5488                   14116
# 27       1     28       138.980568  2017       5500                   14199
# 48       1     49       146.283685  2590       5948                   15847
# 49       1     50       146.593949  2629       5975                   15928
# 50       1     51       147.070279  2667       6001                   16022
#
# ...
